# %% [markdown]
# # Pulling Data from public APIs - GET request

# %%
headers = {"apikey": "ZsV2PxDlF4Mb3oD0zd6mdkv1h3Y3VWXf"}

# %%
base_url = "https://api.apilayer.com/exchangerates_data/latest"

# %% [markdown]
# ## Extracting Data on currency exchnage rates

# %% [markdown]
# ### Sending a GET request

# %%
import requests

# %%
response = requests.get(base_url, headers = headers)

# %% [markdown]
# ### Investigating Response

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{\n    "success": true,\n    "timestamp": 1655577243,\n    "base": "EUR",\n    "date": "2022-06-18",\n    "rates": {\n        "AED": 3.855047,\n        "AFN": 93.867237,\n        "ALL": 119.808183,\n        "AMD": 445.064659,\n        "ANG": 1.895338,\n        "AOA": 455.412029,\n        "ARS": 129.265183,\n        "AUD": 1.51426,\n        "AWG": 1.889685,\n        "AZN": 1.788374,\n        "BAM": 1.955148,\n        "BBD": 2.123459,\n        "BDT": 97.752082,\n        "BGN": 1.954971,\n        "BHD": 0.396462,\n        "BIF": 2163.504871,\n        "BMD": 1.049534,\n        "BND": 1.457391,\n        "BOB": 7.240673,\n        "BRL": 5.409212,\n        "BSD": 1.051633,\n        "BTC": 5.7402218e-05,\n        "BTN": 82.069455,\n        "BWP": 12.840818,\n        "BYN": 3.549961,\n        "BYR": 20570.860148,\n        "BZD": 2.11986,\n        "CAD": 1.368062,\n        "CDF": 2105.364944,\n        "CHF": 1.018937,\n        "CLF": 0.03335,\n        "CLP": 920.235237,\n        "CNY": 7.0494
# ...

# %%
response.content
# Out:
# b'{\n    "success": true,\n    "timestamp": 1655577243,\n    "base": "EUR",\n    "date": "2022-06-18",\n    "rates": {\n        "AED": 3.855047,\n        "AFN": 93.867237,\n        "ALL": 119.808183,\n        "AMD": 445.064659,\n        "ANG": 1.895338,\n        "AOA": 455.412029,\n        "ARS": 129.265183,\n        "AUD": 1.51426,\n        "AWG": 1.889685,\n        "AZN": 1.788374,\n        "BAM": 1.955148,\n        "BBD": 2.123459,\n        "BDT": 97.752082,\n        "BGN": 1.954971,\n        "BHD": 0.396462,\n        "BIF": 2163.504871,\n        "BMD": 1.049534,\n        "BND": 1.457391,\n        "BOB": 7.240673,\n        "BRL": 5.409212,\n        "BSD": 1.051633,\n        "BTC": 5.7402218e-05,\n        "BTN": 82.069455,\n        "BWP": 12.840818,\n        "BYN": 3.549961,\n        "BYR": 20570.860148,\n        "BZD": 2.11986,\n        "CAD": 1.368062,\n        "CDF": 2105.364944,\n        "CHF": 1.018937,\n        "CLF": 0.03335,\n        "CLP": 920.235237,\n        "CNY": 7.049
# ...

# %% [markdown]
# ## Handling Json

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1655577243,
#  'base': 'EUR',
#  'date': '2022-06-18',
#  'rates': {'AED': 3.855047,
#   'AFN': 93.867237,
#   'ALL': 119.808183,
#   'AMD': 445.064659,
#   'ANG': 1.895338,
#   'AOA': 455.412029,
#   'ARS': 129.265183,
#   'AUD': 1.51426,
#   'AWG': 1.889685,
#   'AZN': 1.788374,
#   'BAM': 1.955148,
#   'BBD': 2.123459,
#   'BDT': 97.752082,
#   'BGN': 1.954971,
#   'BHD': 0.396462,
#   'BIF': 2163.504871,
#   'BMD': 1.049534,
#   'BND': 1.457391,
#   'BOB': 7.240673,
#   'BRL': 5.409212,
#   'BSD': 1.051633,
#   'BTC': 5.7402218e-05,
#   'BTN': 82.069455,
#   'BWP': 12.840818,
#   'BYN': 3.549961,
#   'BYR': 20570.860148,
#   'BZD': 2.11986,
#   'CAD': 1.368062,
#   'CDF': 2105.364944,
#   'CHF': 1.018937,
#   'CLF': 0.03335,
#   'CLP': 920.235237,
#   'CNY': 7.049407,
#   'COP': 4099.369196,
#   'CRC': 718.929072,
#   'CUC': 1.049534,
#   'CUP': 27.812643,
#   'CVE': 110.226528,
#   'CZK': 24.72219,
#   'DJF': 187.224653,
#   'DKK': 7.438911,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
import json

# %%
json.dumps(response.json(), indent = 4)
# Out:
# '{\n    "success": true,\n    "timestamp": 1655577243,\n    "base": "EUR",\n    "date": "2022-06-18",\n    "rates": {\n        "AED": 3.855047,\n        "AFN": 93.867237,\n        "ALL": 119.808183,\n        "AMD": 445.064659,\n        "ANG": 1.895338,\n        "AOA": 455.412029,\n        "ARS": 129.265183,\n        "AUD": 1.51426,\n        "AWG": 1.889685,\n        "AZN": 1.788374,\n        "BAM": 1.955148,\n        "BBD": 2.123459,\n        "BDT": 97.752082,\n        "BGN": 1.954971,\n        "BHD": 0.396462,\n        "BIF": 2163.504871,\n        "BMD": 1.049534,\n        "BND": 1.457391,\n        "BOB": 7.240673,\n        "BRL": 5.409212,\n        "BSD": 1.051633,\n        "BTC": 5.7402218e-05,\n        "BTN": 82.069455,\n        "BWP": 12.840818,\n        "BYN": 3.549961,\n        "BYR": 20570.860148,\n        "BZD": 2.11986,\n        "CAD": 1.368062,\n        "CDF": 2105.364944,\n        "CHF": 1.018937,\n        "CLF": 0.03335,\n        "CLP": 920.235237,\n        "CNY": 7.0494
# ...

# %%
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "success": true,
#     "timestamp": 1655577243,
#     "base": "EUR",
#     "date": "2022-06-18",
#     "rates": {
#         "AED": 3.855047,
#         "AFN": 93.867237,
#         "ALL": 119.808183,
#         "AMD": 445.064659,
#         "ANG": 1.895338,
#         "AOA": 455.412029,
#         "ARS": 129.265183,
#         "AUD": 1.51426,
#         "AWG": 1.889685,
#         "AZN": 1.788374,
#         "BAM": 1.955148,
#         "BBD": 2.123459,
#         "BDT": 97.752082,
#         "BGN": 1.954971,
#         "BHD": 0.396462,
#         "BIF": 2163.504871,
#         "BMD": 1.049534,
#         "BND": 1.457391,
#         "BOB": 7.240673,
#         "BRL": 5.409212,
#         "BSD": 1.051633,
#         "BTC": 5.7402218e-05,
#         "BTN": 82.069455,
#         "BWP": 12.840818,
#         "BYN": 3.549961,
#         "BYR": 20570.860148,
#         "BZD": 2.11986,
#         "CAD": 1.368062,
#         "CDF": 2105.364944,
#         "CHF": 1.018937,
#         "CLF": 0.03335,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %% [markdown]
# ## Incorporating parameters in the GET request

# %%
param_url = base_url + '?symbols=USD,GBP'
param_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/latest?symbols=USD,GBP'

# %%
response1 = requests.get(param_url, headers=headers)
response1
# Out:
# <Response [200]>

# %%
data = response1.json()
data
# Out:
# {'success': True,
#  'timestamp': 1655577303,
#  'base': 'EUR',
#  'date': '2022-06-18',
#  'rates': {'USD': 1.049534, 'GBP': 0.858479}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['rates']
# Out:
# {'USD': 1.049534, 'GBP': 0.858479}

# %%
data['date']
# Out:
# '2022-06-18'

# %%
param_urls = base_url + "?symbols=GBP" + "&" + "base=USD"
param_urls
# Out:
# 'https://api.apilayer.com/exchangerates_data/latest?symbols=GBP&base=USD'

# %%
data = requests.get(param_urls, headers=headers).json()
data
# Out:
# {'success': True,
#  'timestamp': 1655577303,
#  'base': 'USD',
#  'date': '2022-06-18',
#  'rates': {'GBP': 0.817962}}

# %%
data['rates']
# Out:
# {'GBP': 0.817962}

# %%
usd_to_gbp = data['rates']['GBP']
usd_to_gbp
# Out:
# 0.817962

# %% [markdown]
# ## Obtaining Historical Exchange rates

# %%
base_url = "https://api.apilayer.com/exchangerates_data"

# %%
historical_url = base_url + '/2016-01-26' 
historical_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/2016-01-26'

# %%
response = requests.get(historical_url, headers = headers)
response.status_code
# Out:
# 200

# %%
data = response.json()
print(json.dumps(data, indent =4))
# Out:
# {
#     "success": true,
#     "timestamp": 1453852799,
#     "historical": true,
#     "base": "EUR",
#     "date": "2016-01-26",
#     "rates": {
#         "AED": 3.991061,
#         "AFN": 74.58154,
#         "ALL": 137.965795,
#         "AMD": 530.247142,
#         "ANG": 1.943586,
#         "AOA": 168.999693,
#         "ARS": 14.990112,
#         "AUD": 1.55192,
#         "AWG": 1.948565,
#         "AZN": 1.738253,
#         "BAM": 1.958195,
#         "BBD": 2.173122,
#         "BDT": 85.139638,
#         "BGN": 1.959586,
#         "BHD": 0.409556,
#         "BIF": 1701.160447,
#         "BMD": 1.086561,
#         "BND": 1.550257,
#         "BOB": 7.503896,
#         "BRL": 4.430875,
#         "BSD": 1.086561,
#         "BTC": 0.002759,
#         "BTN": 73.608145,
#         "BWP": 12.59286,
#         "BYR": 22823.99887,
#         "BZD": 2.166505,
#         "CAD": 1.536042,
#         "CDF": 1008.769361,
#         "CHF": 1.104771,
#         "CLF": 0.026732,
# ...

# %% [markdown]
# ## Obtaining Data for a time period

# %%
time_period = base_url + '/timeseries' + '?start_date=2017-04-26&end_date=2018-04-26' + '&symbols=GBP'
time_period
# Out:
# 'https://api.apilayer.com/exchangerates_data/timeseries?start_date=2017-04-26&end_date=2018-04-26&symbols=GBP'

# %%
response = requests.get(time_period, headers = headers)
response.status_code
# Out:
# 200

# %%
data = response.json()
print(json.dumps(data, indent = 4))
# Out:
# {
#     "success": true,
#     "timeseries": true,
#     "start_date": "2017-04-26",
#     "end_date": "2018-04-26",
#     "base": "EUR",
#     "rates": {
#         "2017-04-26": {
#             "GBP": 0.849233
#         },
#         "2017-04-27": {
#             "GBP": 0.842886
#         },
#         "2017-04-28": {
#             "GBP": 0.841437
#         },
#         "2017-04-29": {
#             "GBP": 0.841437
#         },
#         "2017-04-30": {
#             "GBP": 0.843718
#         },
#         "2017-05-01": {
#             "GBP": 0.846159
#         },
#         "2017-05-02": {
#             "GBP": 0.845241
#         },
#         "2017-05-03": {
#             "GBP": 0.846057
#         },
#         "2017-05-04": {
#             "GBP": 0.849792
#         },
#         "2017-05-05": {
#             "GBP": 0.847757
#         },
#         "2017-05-06": {
#             "GBP": 0.847757
#         },
#         "2017-05-07": {
#             "GBP": 0.845862
#         },
# ...

# %% [markdown]
# ## Coding a Simple Currency Conversion Calculator

# %%
date = input("Please enter the date (in the format 'yyyy-mm-dd' or 'latest'):")
base = input("convert from (currency):")
curr = input("convert to (currency):")
quan = float(input("How much {} do you want to convert:".format(base)))

url = base_url + "/" + date + "?base=" + base + "&symbols=" + curr
response = requests.get(url, headers=headers)

if (response.ok is False):
    print("\n Error {}".format(response.status_code))
    print(response.json()['error'])

else:
    data = response.json()
    rate = data['rates'][curr]
    
    result = quan*rate
    
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan, base, result, curr, data['date']))
# Out:
# Please enter the date (in the format 'yyyy-mm-dd' or 'latest'):2009-07-03
# convert from (currency):NGN
# convert to (currency):USD
# How much NGN do you want to convert:10000
#
# 10000.0 NGN is equal to 67.57 USD, based upon exchange rates on 2009-07-03

# %% [markdown]
# ## Another example: the iTunes search API

# %% [markdown]
# ### Passing parameters in the request

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site + "?term=the+beatles&country=us"

requests.get(url, headers=headers)
# Out:
# <Response [200]>

# %%
r = requests.get(base_site, params = {"term": "the beatles", "country": "us"}, headers = headers)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us'

# %% [markdown]
#  ## Investigating the output and Parameters

# %%
info = r.json()
print(json.dumps(info, indent = 4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "audiobook",
#             "artistId": 160778930,
#             "collectionId": 1439484338,
#             "artistName": "Bob Spitz",
#             "collectionName": "The Beatles (Abridged)",
#             "collectionCensoredName": "The Beatles (Abridged)",
#             "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#             "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#             "collectionPrice": 16.99,
#             "collectionExplicitness": "notExplicit",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
 print(json.dumps(info['results'][0], indent =4))
# Out:
# {
#     "wrapperType": "audiobook",
#     "artistId": 160778930,
#     "collectionId": 1439484338,
#     "artistName": "Bob Spitz",
#     "collectionName": "The Beatles (Abridged)",
#     "collectionCensoredName": "The Beatles (Abridged)",
#     "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#     "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#     "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#     "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#     "collectionPrice": 16.99,
#     "collectionExplicitness": "notExplicit",
#     "trackCount": 1,
#     "country": "USA",
#     "currency": "USD",
#     "releaseDate": "2005-11-01T08:00:00Z",
#     "primaryGenreName": "Biographies & Memoirs",
# ...

# %%
info["resultCount"]
# Out:
# 50

# %%
r = requests.get(base_site, params ={"term": "the beatles", "country": "us", "limit": 200}, headers = headers)
r.ok
# Out:
# True

# %%
r.json()["resultCount"]
# Out:
# 200

# %%
r = requests.get(base_site, params = {"term": "bts", "intermediary": "sk"}, headers = headers)
r.ok
# Out:
# True

# %%
r.json()
# Out:
# {'resultCount': 50,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 201714418,
#    'collectionId': 1077051655,
#    'trackId': 1077051656,
#    'artistName': 'Wiz Khalifa',
#    'collectionName': 'Khalifa',
#    'trackName': 'BTS',
#    'collectionCensoredName': 'Khalifa',
#    'trackCensoredName': 'BTS',
#    'artistViewUrl': 'https://music.apple.com/us/artist/wiz-khalifa/201714418?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/bts/1077051655?i=1077051656&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/bts/1077051655?i=1077051656&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/10/b6/33/10b6333a-0d49-35ba-797c-0dcedd9e7a50/mzaf_16358376002976953877.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music69/v4/06/fd/ea/06fdea4a-558f-73b1-abc5-8eef0822368d/075679913487.jpg/30x30bb.jpg',
# ...

# %%
r.json().keys()
# Out:
# dict_keys(['resultCount', 'results'])
